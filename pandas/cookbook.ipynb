# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]})
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df.ix[df.AAA>=5, 'BBB'] = -1
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   -1   50
# 2    6   -1  -30
# 3    7   -1  -50

# %%
df.ix[df['AAA']>=5, ['BBB', 'CCC']] = 555
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5  555  555
# 2    6  555  555
# 3    7  555  555

# %%
df.ix[df.AAA<5, ['BBB','CCC']] = 2000
df
# Out:
#    AAA   BBB   CCC
# 0    4  2000  2000
# 1    5   555   555
# 2    6   555   555
# 3    7   555   555

# %%
df_mask = pd.DataFrame({'AAA' : [True]*4, 'BBB' : [False]*4,'CCC' : [True,False]*2})
df.where(df_mask,-1000)
df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df['logic'] = np.where(df['AAA']>5, 'high', 'low')
df
# Out:
#    AAA  BBB  CCC logic
# 0    4   10  100   low
# 1    5   20   50   low
# 2    6   30  -30  high
# 3    7   40  -50  high

# %%
dflow = df[df.AAA<=5]
dfhigh = df[df.AAA>5]
dflow
dfhigh
# Out:
#    AAA  BBB  CCC
# 2    6   30  -30
# 3    7   40  -50

# %%
newseries = df.loc[(df['BBB']<25)&(df['CCC']>=-40), 'AAA']
newseries
# Out:
# 0    4
# 1    5
# Name: AAA, dtype: int64

# %%
df.loc[(df['BBB']>25) | (df['CCC']>=75), 'AAA'] = 0.1
df
# Out:
#    AAA  BBB  CCC
# 0  0.1   10  100
# 1  5.0   20   50
# 2  0.1   30  -30
# 3  0.1   40  -50

# %%
df = pd.DataFrame({'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]})
aValue = 43.0
df.ix[(df.CCC-aValue).abs().argsort()]#按和aValue的接近程度排序
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 0    4   10  100
# 2    6   30  -30
# 3    7   40  -50

# %%
import functools
df = pd.DataFrame({'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]})
Crit1 = df.AAA <= 5.5
Crit2 = df.BBB == 10.0
Crit3 = df.CCC > -40.0
AllCrit = Crit1 & Crit2 & Crit3
print(Crit1)
print(AllCrit)
print(df[AllCrit])
CritList = [Crit1, Crit2, Crit3]
AllCrit = functools.reduce(lambda x,y: x&y, CritList)#reduce(lambda x, y: x+y, [1, 2, 3, 4, 5]) calculates ((((1+2)+3)+4)+5)
print(AllCrit)
print(df[AllCrit])
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: AAA, dtype: bool
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool
#    AAA  BBB  CCC
# 0    4   10  100
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool
#    AAA  BBB  CCC
# 0    4   10  100

# %%
df = pd.DataFrame({'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]})
df[(df.AAA<=6)&(df.index.isin([0, 2, 4]))]#isin函数
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 2    6   30  -30

# %%
data = {'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]}
df = pd.DataFrame(data=data, index=['foo','bar','boo','kar'])
df
# Out:
#      AAA  BBB  CCC
# foo    4   10  100
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
df.loc['bar':'kar'] #label
# Out:
#      AAA  BBB  CCC
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
df.ix[0:3] #Same as .iloc[0:3]
# Out:
#      AAA  BBB  CCC
# foo    4   10  100
# bar    5   20   50
# boo    6   30  -30

# %%
df.ix['bar':'kar']#Same as .loc['bar':'kar']
# Out:
#      AAA  BBB  CCC
# bar    5   20   50
# boo    6   30  -30
# kar    7   40  -50

# %%
data = {'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]}
df2 = pd.DataFrame(data=data, index=[1,2,3,4]) #Note index starts at 1
print(df2)
df2.iloc[1:3]#Position-oriented
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30
# 4    7   40  -50
#    AAA  BBB  CCC
# 2    5   20   50
# 3    6   30  -30

# %%
df2.loc[1:3] #Label-oriented
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30

# %%
df2.ix[1:3]#General, will mimic loc (label-oriented)
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30

# %%
df2.ix[0:3] #General, will mimic iloc(position-oriented), as loc[0:3] would raise a KeyError
# Out:
#    AAA  BBB  CCC
# 1    4   10  100
# 2    5   20   50
# 3    6   30  -30

# %%
df = pd.DataFrame({'AAA':[4,5,6,7], 'BBB':[10,20,30,40], 'CCC':[100,50,-30,-50]})
df[~((df.AAA<=6)&(df.index.isin([0, 2, 4])))]#inverse operator(~)
# Out:
#    AAA  BBB  CCC
# 1    5   20   50
# 3    7   40  -50

# %%
'''
7.2.2 Panels
'''
rng = pd.date_range('1/1/2013', periods=100, freq='D')
data = np.random.randn(100, 4)
cols = ['A', 'B', 'C', 'D']
df1, df2, df3 = pd.DataFrame(data, rng, cols), pd.DataFrame(data, rng, cols), pd.DataFrame(data, rng, cols)
pf = pd.Panel({'df1':df1, 'df2':df2, 'df3':df3})
pf
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 3 (items) x 100 (major_axis) x 4 (minor_axis)
# Items axis: df1 to df3
# Major_axis axis: 2013-01-01 00:00:00 to 2013-04-10 00:00:00
# Minor_axis axis: A to D

# %%
df = pd.DataFrame({'AAA':[1,2,1,3], 'BBB':[1,1,2,2], 'CCC':[2,1,3,1]})
source_rows = df.index
source_cols = df.columns
print("rows:%s  cols:%s" % (source_rows, source_cols))
new_cols = [str(x)+'_cat' for x in source_cols]
print('new_cols:%s' % new_cols)
categories = {1:'Alpha', 2:'Beta', 3:'Charlie'}
df[new_cols] = df[source_cols].applymap(categories.get)
print(df)
# Out:
# rows:Int64Index([0, 1, 2, 3], dtype='int64')  cols:Index([u'AAA', u'BBB', u'CCC'], dtype='object')
# new_cols:['AAA_cat', 'BBB_cat', 'CCC_cat']
#    AAA  BBB  CCC  AAA_cat BBB_cat  CCC_cat
# 0    1    1    2    Alpha   Alpha     Beta
# 1    2    1    1     Beta   Alpha    Alpha
# 2    1    2    3    Alpha    Beta  Charlie
# 3    3    2    1  Charlie    Beta    Alpha

# %%
df = pd.DataFrame({'AAA':[1,1,1,2,2,2,3,3], 'BBB':[2,1,3,4,5,1,2,3]})
df.loc[df.groupby("AAA")["BBB"].idxmin()] #idxmin() to get the index of the mins
# Out:
#    AAA  BBB
# 1    1    1
# 5    2    1
# 0    1    2
# 6    3    2
# 2    1    3
# 7    3    3
# 3    2    4
# 4    2    5

# %%
df.sort('BBB').groupby('AAA', as_index=False).first() #sort then take first of each
# Out:
#    AAA  BBB
# 0    1    1
# 1    2    1
# 2    3    2

# %%
df = pd.DataFrame({'row':[0,1,2], 'One_X':[1.1,1.1,1.1],
                   'One_Y':[1.2,1.2,1.2], 'Two_X':[1.11,1.11,1.11], 'Two_Y':[1.22,1.22,1.22]})
df
# Out:
#    One_X  One_Y  Two_X  Two_Y  row
# 0    1.1    1.2   1.11   1.22    0
# 1    1.1    1.2   1.11   1.22    1
# 2    1.1    1.2   1.11   1.22    2

# %%
df = df.set_index('row')
df
# Out:
#      One_X  One_Y  Two_X  Two_Y
# row
# 0      1.1    1.2   1.11   1.22
# 1      1.1    1.2   1.11   1.22
# 2      1.1    1.2   1.11   1.22

# %%
df.columns = pd.MultiIndex.from_tuples([tuple(c.split('_')) for c in df.columns])
df
# Out:
#      One        Two
#        X    Y     X     Y
# row
# 0    1.1  1.2  1.11  1.22
# 1    1.1  1.2  1.11  1.22
# 2    1.1  1.2  1.11  1.22

# %%
df.stack(0)
# Out:
#             X     Y
# row
# 0   One  1.10  1.20
#     Two  1.11  1.22
# 1   One  1.10  1.20
#     Two  1.11  1.22
# 2   One  1.10  1.20
#     Two  1.11  1.22

# %%
df.stack(1)
# Out:
#        One   Two
# row
# 0   X  1.1  1.11
#     Y  1.2  1.22
# 1   X  1.1  1.11
#     Y  1.2  1.22
# 2   X  1.1  1.11
#     Y  1.2  1.22

# %%
df = df.stack(0).reset_index(1)
df
# Out:
#     level_1     X     Y
# row
# 0       One  1.10  1.20
# 0       Two  1.11  1.22
# 1       One  1.10  1.20
# 1       Two  1.11  1.22
# 2       One  1.10  1.20
# 2       Two  1.11  1.22

# %%
df.columns = ['Sample','All_X','All_Y']
df
# Out:
#     Sample  All_X  All_Y
# row
# 0      One   1.10   1.20
# 0      Two   1.11   1.22
# 1      One   1.10   1.20
# 1      Two   1.11   1.22
# 2      One   1.10   1.20
# 2      Two   1.11   1.22

# %%
tuples = [(x,y) for x in ['A','B','C'] for y in ['O','I']]
print(tuples)
cols = pd.MultiIndex.from_tuples(tuples)
print(cols)
df = pd.DataFrame(np.random.randn(2,6),index=['n','m'],columns=cols)
print(df)
df = df.div(df['C'], level=1)
print(df)
# Out:
# [('A', 'O'), ('A', 'I'), ('B', 'O'), ('B', 'I'), ('C', 'O'), ('C', 'I')]
#
# A  O
#    I
# B  O
#    I
# C  O
#    I
#           A                   B                   C
#           O         I         O         I         O         I
# n  0.929833  0.581406  1.501907 -0.353255 -0.176667 -1.319203
# m  0.714941 -0.644924 -0.570133 -0.723050  0.050267 -0.765882
#            A                    B            C
#            O         I          O         I  O  I
# n  -5.263191 -0.440726  -8.501334  0.267779  1  1
# m  14.222896  0.842067 -11.342112  0.944074  1  1

# %%
##DataFrame.xs
coords = [('AA','one'),('AA','six'),('BB','one'),('BB','two'),('BB','six')]
index = pd.MultiIndex.from_tuples(coords)
print(index)
df = pd.DataFrame([11,22,33,44,55], index, ['MyData'])
print(df)
t = df.xs('BB',level=0,axis=0)#To take the cross section of the 1st level and 1st axis the index
print(t)
t = df.xs('six', level=1, axis=0)#2nd level of the 1st axis
print(t)
# Out:
#
# AA  one
#     six
# BB  one
#     two
#     six
#         MyData
# AA one      11
#    six      22
# BB one      33
#    two      44
#    six      55
#      MyData
# one      33
# two      44
# six      55
#     MyData
# AA      22
# BB      55

# %%
import itertools
index = list(itertools.product(['Ada','Quinn','Violet'],['Comp','Math','Sci']))
print(index)
headr = list(itertools.product(['Exams','Labs'],['I','II']))
indx = pd.MultiIndex.from_tuples(index,names=['Student','Course'])
print(indx)
cols = pd.MultiIndex.from_tuples(headr)
print(cols)
data = [[70+x+y+(x*y)%3 for x in range(4)] for y in range(9)]
print(data)
df = pd.DataFrame(data,indx,cols)
print(df)
All = slice(None)
print(df.loc['Violet'])
print(df.loc[(All,'Math'),All])
print(df.loc[(slice('Ada','Quinn'),'Math'),All])
print(df.loc[(All,'Math'),('Exams')])
print(df.loc[(All,'Math'),(All,'II')])
df.sort(('Labs','II'), ascending=False)
# Out:
# [('Ada', 'Comp'), ('Ada', 'Math'), ('Ada', 'Sci'), ('Quinn', 'Comp'), ('Quinn', 'Math'), ('Quinn', 'Sci'), ('Violet', 'Comp'), ('Violet', 'Math'), ('Violet', 'Sci')]
# Student  Course
# Ada      Comp
#          Math
#          Sci
# Quinn    Comp
#          Math
#          Sci
# Violet   Comp
#          Math
#          Sci
#
# Exams  I
#        II
# Labs   I
#        II
# [[70, 71, 72, 73], [71, 73, 75, 74], [72, 75, 75, 75], [73, 74, 75, 76], [74, 76, 78, 77], [75, 78, 78, 78], [76, 77, 78, 79], [77, 79, 81, 80], [78, 81, 81, 81]]
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Ada     Comp      70  71   72  73
#         Math      71  73   75  74
#         Sci       72  75   75  75
# Quinn   Comp      73  74   75  76
#         Math      74  76   78  77
#         Sci       75  78   78  78
# Violet  Comp      76  77   78  79
#         Math      77  79   81  80
#         Sci       78  81   81  81
#        Exams     Labs
#            I  II    I  II
# Course
# Comp      76  77   78  79
# Math      77  79   81  80
# Sci       78  81   81  81
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Ada     Math      71  73   75  74
# Quinn   Math      74  76   78  77
# Violet  Math      77  79   81  80
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Ada     Math      71  73   75  74
# Quinn   Math      74  76   78  77
#                  I  II
# Student Course
# Ada     Math    71  73
# Quinn   Math    74  76
# Violet  Math    77  79
#                Exams Labs
#                   II   II
# Student Course
# Ada     Math      73   74
# Quinn   Math      76   77
# Violet  Math      79   80
#                Exams     Labs
#                    I  II    I  II
# Student Course
# Violet  Sci       78  81   81  81
#         Math      77  79   81  80
#         Comp      76  77   78  79
# Quinn   Sci       75  78   78  78
#         Math      74  76   78  77
#         Comp      73  74   75  76
# Ada     Sci       72  75   75  75
#         Math      71  73   75  74
#         Comp      70  71   72  73

# %%
df = pd.DataFrame(np.random.randn(6,1), index=pd.date_range('2013-08-01', periods=6, freq='B'), columns=list('A'))
print(df)
df.ix[3,'A'] = np.nan
print(df)
df.reindex(df.index[::-1]).ffill()
# Out:
#                    A
# 2013-08-01 -1.389980
# 2013-08-02  0.108299
# 2013-08-05  0.574154
# 2013-08-06  1.625920
# 2013-08-07  0.512698
# 2013-08-08  0.284828
#                    A
# 2013-08-01 -1.389980
# 2013-08-02  0.108299
# 2013-08-05  0.574154
# 2013-08-06       NaN
# 2013-08-07  0.512698
# 2013-08-08  0.284828
#                    A
# 2013-08-08  0.284828
# 2013-08-07  0.512698
# 2013-08-06  0.512698
# 2013-08-05  0.574154
# 2013-08-02  0.108299
# 2013-08-01 -1.389980
